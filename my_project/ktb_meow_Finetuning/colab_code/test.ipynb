# %%
chat = [
    {"role": "tool_list", "content": ""},
    {"role": "system", "content": "- AI 언어모델의 이름은 \"CLOVA X\" 이며 네이버에서 만들었다..."},
    {"role": "user", "content": "슈뢰딩거 방정식과 양자역학의 관계를 최대한 자세히 알려줘."},
]

# %%
eos = tokenizer.eos_token if tokenizer else "</s>"

def get_chat_prompt(content, emotion, post_type, transformed_content):
    system_prompt = "너는 동물 유형과 감정에 맞게 문장을 자연스럽게 변환하는 전문가야."
    user_prompt = (
        f"다음 문장을 {emotion} {post_type} 말투로 바꿔줘.\n"
        f"Input: {content}\n"
        f"Output:"
    )
    response = f"{transformed_content}{eos}"
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": response}
    ]
